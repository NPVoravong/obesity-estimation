# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
data_file = "https://obesity-001.s3.us-east-2.amazonaws.com/obesity_numeric.csv"
data_df = pd.read_csv(data_file)

# %%
data_df
# Out:
#       Gender   Age  Height  Weight  family_history_with_overweight  FAVC  \
# 0          0  21.0     1.6    64.0                               1     0
# 1          0  21.0     1.5    56.0                               1     0
# 2          1  23.0     1.8    77.0                               1     0
# 3          1  27.0     1.8    87.0                               0     0
# 4          1  22.0     1.8    89.8                               0     0
# ...      ...   ...     ...     ...                             ...   ...
# 2106       0  21.0     1.7   131.4                               1     1
# 2107       0  22.0     1.7   133.7                               1     1
# 2108       0  23.0     1.8   133.7                               1     1
# 2109       0  24.0     1.7   133.3                               1     1
# 2110       0  24.0     1.7   133.5                               1     1
#
#       FCVC  NCP  CAEC  SMOKE  CH2O  SCC  FAF  TUE  CALC  MTRANS  NObeyesdad
# ...

# %%
# change to config import
rds_connection_string = 'postgres:awsdbpassword001@aws-pg-db001.cy0jvyctgrrb.us-east-2.rds.amazonaws.com/obesity'
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
engine.table_names()
# Out:
# ['numeric']

# %%
data_df.to_sql(name='numeric', con=engine, if_exists='replace', index=False)
